# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('../images/img1.jpg')

# %%
blurred_image = cv2.GaussianBlur(image,(5,5),1.5)

# %%
concat_image = cv2.hconcat([image,blurred_image])

# %%
plt.imshow(concat_image)
plt.title('Original VS Gaussian Blur Image')
plt.show()
